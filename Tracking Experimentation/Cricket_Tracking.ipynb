# %%
pip install trackers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.9/210.9 kB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 7.0 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.2 MB/s eta 0:00:00
# ...

# %%
import supervision as sv
from trackers import SORTTracker
from ultralytics import YOLO

tracker = SORTTracker()
model = YOLO("yolo11m.pt")
annotator = sv.LabelAnnotator(text_position=sv.Position.CENTER)

def callback(frame, _):
    result = model(frame)[0]
    detections = sv.Detections.from_ultralytics(result)
    detections = tracker.update(detections)
    return annotator.annotate(frame, detections, labels=detections.tracker_id)

sv.process_video(
    source_path="/content/cricket_clip.mp4",
    target_path="/content/results/output.mp4",
    callback=callback,
)
# Out:
# 0: 384x640 12 persons, 846.1ms
# Speed: 2.8ms preprocess, 846.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 804.8ms
# Speed: 3.6ms preprocess, 804.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 796.8ms
# Speed: 3.7ms preprocess, 796.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 794.0ms
# Speed: 4.2ms preprocess, 794.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 793.7ms
# Speed: 3.4ms preprocess, 793.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 812.0ms
# Speed: 3.8ms preprocess, 812.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 806.0ms
# Speed: 3.4ms preprocess, 806.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1241.0ms
# ...

# %%
# !pip install rfdetr

# %%
import supervision as sv
from trackers import SORTTracker
from rfdetr import RFDETRBase

tracker = SORTTracker()
model = RFDETRBase()
annotator = sv.LabelAnnotator(text_position=sv.Position.CENTER)

def callback(frame, _):
    detections = model.predict(frame)
    detections = tracker.update(detections)
    labels = [str(x) for x in detections.tracker_id]  # Convert IDs to strings
    return annotator.annotate(frame, detections, labels=labels)

sv.process_video(
    source_path="/content/cricket_clip.mp4",
    target_path="/content/results/results.mp4",
    callback=callback,
)
# Out:
# Loading pretrain weights
